# %%
import os
import pandas as pd
from pytubefix import Playlist as pl, YouTube as yt

# %% [markdown]
# ## Data Collection and Weak Annotation Based on Playlist Complexity Level Estimation

# %%
playlist_df = pd.read_csv('classified_video_playlist_urls.csv')
playlist_df.head()
# Out:
#                      Channel Name  \
# 0                  Homeschool Pop
# 1                 Rachel Randazzo
# 2                Math and Science
# 3               The Learning Bees
# 4  EasyElimu Learning Innovations
#
#                                   Video Playlist URL Complexity Level  \
# 0  https://youtube.com/playlist?list=PLNmq_T1B9lj...           Simple
# 1  https://youtube.com/playlist?list=PLGV8Dna9QsU...           Simple
# 2  https://youtube.com/playlist?list=PLnVYEpTNGNt...           Simple
# 3  https://youtube.com/playlist?list=PLgBd17cQkVt...           Simple
# 4  https://youtube.com/playlist?list=PL9jFeeMFHxs...           Simple
#
#    No. of Extracted Video URLs
# 0                           12
# 1                            8
# 2                           12
# 3                           12
# 4                            8

# %%
playlist_urls = list(playlist_df['Video Playlist URL'])
playlist_urls
# Out:
# ['https://youtube.com/playlist?list=PLNmq_T1B9ljIg4yu14mzNas7hvwM5aZ2l&si=tfhs-CC2r8ZCmZZ',
#  'https://youtube.com/playlist?list=PLGV8Dna9QsUwSDK_agDCT-24X_SfCrduE&si=dQdC6OPe5i6LYB-W',
#  'https://youtube.com/playlist?list=PLnVYEpTNGNtWNqjyerNHdzNHWema_0n2W&si=Grp6Z2eO2PLXw0jI',
#  'https://youtube.com/playlist?list=PLgBd17cQkVtCbajlUEkmfbPS5s4OUF0KU&si=DRp5JTIaE74-arae',
#  'https://youtube.com/playlist?list=PL9jFeeMFHxsM3epT4vRyuwuPN7QDk8PY7&si=RAHiA5hGvuglA379',
#  'https://youtube.com/playlist?list=PLKnB100k_YZkaH9sZ7tkOdR6JEQRdde28&si=9QVugbAXoM5XoJ3S',
#  'https://youtube.com/playlist?list=PLBlnK6fEyqRgKEkaJvAe8oA6m_bUqt-MC&si=6uD5zItGuKm5Tbnr',
#  'https://youtube.com/playlist?list=PLOspHqNVtKAC-FUNMq8qjYVw6_semZHw0&si=zqKxBtXwPqAxYJe1',
#  'https://youtube.com/playlist?list=PLU_DCVXL8MyOFBXC-dO214lr1Uibp4TCi&si=ww0YX7bFuGHrJwqt',
#  'https://youtube.com/playlist?list=PLKi4WTp6PRGX8NtQpzliTlMceQT1ua24f&si=6czQRzScE8u5NeRe',
#  'https://youtube.com/playlist?list=PL9jFeeMFHxsOaoR6toc3RJmY5aycYcmGj&si=xBlbVthIjPgKakfr',
#  'https://youtube.com/playlist?list=PL9jFeeMFHxsNYt_SbmbQq6LiB98Cl0npQ&si=gjx-1inbEbcXwiTK',
#  'https://youtube.com/playlist?list=PLgy93B3fzSxBqmtxU_SjkeiNOjfB4a7g1&si=A4lk5Z0nfIowoPFO',
#  'https://youtube.com/playlist?list=PLgy93B3fzSxDva5h2ugPTT6iTX-JNmLyO&si=iBYgPvOljSDLLRwy',
#  'https://youtube.com/playlist?list=PLgy93B3fzSxDCDdRSLCWG8ivCGrAgsFDw&si=CAjUBMOel5ZtvOY3',
#  'https://youtube.com/playlist?list=PL0HYJZ0CuE4pK2xYBeiKznO87ecTPZn5f&si=nxwSvvA3V98gcA06',
#  'https://youtube.com/playlist?list=PL9jFeeMFHxsMUEnW2o5LOjGI3-EJStZh-&si=vLc7-eEeQlDmXAcU',
#  'https://youtube.com/playlist?list=PL9jFeeMFHxsOuCY-on9WCPhtgOfVBmQi_&si=VO9u3YRIABmU9BlK',
#  'https://youtube.com/playlist?list=PLVLoWQFkZbhXq3hjhx5TQMhL3lNiF_OLy&si=CxENRiffHXemFHD5']

# %%
# extract the specified number of urls and names of videos that are under 11 minutes from each playlist
# only a certain number of urls are extracted from each playlist to include the different presentation styles followed by different channels in the dataset
data = []

for n, p_url in enumerate(playlist_urls):
    p_url_object = pl(p_url)
    
    num_extracted_urls = 0
    num_urls_to_extract = playlist_df.loc[n]['No. of Extracted Video URLs']
    
    for v_url in p_url_object.video_urls:
        # ensure the number of extracted urls does not exceed the amount specified in the playlist dataset
        if num_extracted_urls == num_urls_to_extract:
            break
            
        v_url_object = yt(v_url)
        
        # ensure the video's duration is under 11 minutes (660 seconds)
        if v_url_object.length < 660:
            data.append([v_url_object.title, v_url, playlist_df.loc[n]['Complexity Level']])
            num_extracted_urls += 1
                
    print(f"Playlist {n+1}: Extracted successfully")
# Out:
# Playlist 1: Extracted successfully
# Playlist 2: Extracted successfully
# Playlist 3: Extracted successfully
# Playlist 4: Extracted successfully
# Playlist 5: Extracted successfully
# Playlist 6: Extracted successfully
# Playlist 7: Extracted successfully
# Playlist 8: Extracted successfully
# Playlist 9: Extracted successfully
# Playlist 10: Extracted successfully
# Playlist 11: Extracted successfully
# Playlist 12: Extracted successfully
# Playlist 13: Extracted successfully
# Playlist 14: Extracted successfully
# Playlist 15: Extracted successfully
# Playlist 16: Extracted successfully
# Playlist 17: Extracted successfully
# Playlist 18: Extracted successfully
# Playlist 19: Extracted successfully

# %%
# check if the extracted video names and urls are stored and classified properly
data
# Out:
# [['Plant Parts and Functions for Kids',
#   'https://www.youtube.com/watch?v=18amLZ9vfG8',
#   'Simple'],
#  ['Adjectives for Kids | Homeschool Pop',
#   'https://www.youtube.com/watch?v=4jxXnHSbicY',
#   'Simple'],
#  ['Roman Numerals For Kids',
#   'https://www.youtube.com/watch?v=NrnXsKYpLJM',
#   'Simple'],
#  ['Benjamin Franklin for Kids',
#   'https://www.youtube.com/watch?v=5LcMXnZfFFY',
#   'Simple'],
#  ['Paul Revere for Kids',
#   'https://www.youtube.com/watch?v=dmwcfaythY4',
#   'Simple'],
#  ['Thomas Jefferson for Kids',
#   'https://www.youtube.com/watch?v=uL_6b-k7aVI',
#   'Simple'],
#  ['Davy Crockett for Kids',
#   'https://www.youtube.com/watch?v=Pxt_uA8w-t4',
#   'Simple'],
#  ['Susan B. Anthony for Kids',
#   'https://www.youtube.com/watch?v=v23V-cHPpz4',
#   'Simple'],
#  ['George Washington Carver for Kids',
#   'https://www.youtube.com/watch?v=X9Xyw43cC7M',
#   'Simple'],
#  ['Jackie Robinson for Kids | Biography Video',
#   'https://www.youtube.com/watch?v=wMMwBhkxBv0',
#   'Simple'],
#  ['Urban, Suburban and Rural Areas for Kids',
#   'https://www.youtube.com/watch?v=YRxNQPmj1-8',
#   'Simple'],
#  ['Goods and Services for Kids',
#   'https://www.youtube.com/watch?v=Jd4kD9TicbA',
#   'Simple'],
#  ['The History of Civilization for Kids: How Civilization Began - FreeSchool',
#   'https://www.youtube.com/watch?v=IAQAAJo1fI0',
#   'Simple'],
#  ['Traits of Civilization',
#   'https://www.youtube.com/watch?v=J2exRx5QMRU',
#   'Simple'],
#  ['Ancient Greece for Kids | History Learning Video',
#   'https://www.youtube.com/watch?v=jloEzVh31TE',
#   'Simple'],
#  ['Ancient Egypt for Kids',
#   'https://www.youtube.com/watch?v=lBYmOuajdC8',
#   'Simple'],
#  ['Ancient Egypt 101 | National Geographic',
#   'https://www.youtube.com/watch?v=hO1tzmi1V5g',
#   'Simple'],
#  ['Indus Valley Civilization: Crash Course World History #2',
#   'https://www.youtube.com/watch?v=n7ndRwqJYDM',
#   'Simple'],
#  ['Ancient Mesopotamia 101 | National Geographic',
#   'https://www.youtube.com/watch?v=xVf5kZA0HtQ',
#   'Simple'],
#  ['Indus Valley Civilization Facts - History of Ancient India | Educational Videos by Mocomi',
#   'https://www.youtube.com/watch?v=KhDY4KJuvc0',
#   'Simple'],
#  ['01 - Review Of Fraction Concepts - (5th Grade Math)',
#   'https://www.youtube.com/watch?v=xlK8Smp5Ug8',
#   'Simple'],
#  ['Lesson 2 - Writing Fractions As Words - (5th Grade Math)',
#   'https://www.youtube.com/watch?v=SKEmIj-YCPc',
#   'Simple'],
#  ['Lesson 3 - Finding Factors Of Numbers - (5th Grade Math)',
#   'https://www.youtube.com/watch?v=OWlvooseo_o',
#   'Simple'],
#  ['Lesson 4 - Finding The Greatest Common Factor - (5th Grade Math)',
#   'https://www.youtube.com/watch?v=U0-sgUCXHxA',
#   'Simple'],
#  ['Lesson 5 - Finding The GCF Of 3 Numbers - (5th Grade Math)',
#   'https://www.youtube.com/watch?v=2hWAL_HERag',
#   'Simple'],
#  ['Lesson 6 - Prime Factorization - (5th Grade Math)',
#   'https://www.youtube.com/watch?v=R68uRLRJssA',
#   'Simple'],
#  ['Lesson 7 -  Equivalent Fractions - (5th Grade Math)',
#   'https://www.youtube.com/watch?v=vzUaMZd5IeU',
#   'Simple'],
#  ['Lesson 8 - Renaming Fractions - (5th Grade Math)',
#   'https://www.youtube.com/watch?v=vxth4e33HUU',
#   'Simple'],
#  ['Lesson 9 - Simplifying Fractions, Part 1 - (5th Grade Math)',
#   'https://www.youtube.com/watch?v=7TgsXK0ZUu8',
#   'Simple'],
#  ['Lesson 10 - Simplifying Fractions, Part 2 (5th Grade Math)',
#   'https://www.youtube.com/watch?v=ZfO4TzfcTc0',
#   'Simple'],
#  ['Lesson 11 - Review Of Improper Fractions - (5th Grade Math)',
#   'https://www.youtube.com/watch?v=LDqQ9y5ILEc',
#   'Simple'],
#  ['Lesson 12 - Review Of Mixed Fractions - (5th Grade Math)',
#   'https://www.youtube.com/watch?v=xOHGaNF0tIg',
#   'Simple'],
#  ['Microscope (Parts and Functions) | Grade 7 Science DepEd MELC Quarter 2 Module 1',
#   'https://www.youtube.com/watch?v=ZEF9mnL9_W0',
#   'Simple'],
#  ['How to Use a Microscope, Magnification | Grade 7 Science DepEd MELC Quarter 2 Module 2',
#   'https://www.youtube.com/watch?v=c6vUNJzoON0',
#   'Simple'],
#  ['Levels of Biological Organization | Grade 7 Science DepEd MELC Quarter 2 Module 3',
#   'https://www.youtube.com/watch?v=ksLh67GPBTc',
#   'Simple'],
#  ['Types of Reproduction: Sexual and Asexual | Grade 7 Science DepEd MELC Quarter 2 Module 5',
#   'https://www.youtube.com/watch?v=9AIBnaow5a0',
#   'Simple'],
#  ['Biotic & Abiotic Component, Ecological Relationships | Grade 7 Science DepEd MELC Quarter 2 Module 6',
#   'https://www.youtube.com/watch?v=IZoIvJEiNaM',
#   'Simple'],
#  ['Effect of Changes in the Abiotic Factor on Ecosystem | Grade 7 Science DepEd MELC Quarter 2 Module 7',
#   'https://www.youtube.com/watch?v=wAPpAxfsars',
#   'Simple'],
#  ['Visualizing Motion Using Tape Charts & Motion Graphs | Grade 7 Science DepEd MELC Quarter 3 Module 2',
#   'https://www.youtube.com/watch?v=ImkN3lC36vA',
#   'Simple'],
#  ['Characteristics of Light | Grade 7 Science DepEd MELC Quarter 3 Module 4',
#   'https://www.youtube.com/watch?v=nuAA9OEINGc',
#   'Simple'],
#  ['Equivalent vectors - (Lesson 1 of 16 Mathematics Form 2 Topic Vectors I )',
#   'https://www.youtube.com/watch?v=tngxz1Jr3ME',
#   'Simple'],
#  ['Product of a Negative Scalar and a Vector   - (Lesson 4 of 16 Mathematics Form 2 Topic Vectors I )',
#   'https://www.youtube.com/watch?v=AKTvZCjowT4',
#   'Simple'],
#  ['Fractional scalar and a vector  - (Lesson 5 of 16 Mathematics Form 2 Topic Vectors I )',
#   'https://www.youtube.com/watch?v=CvUiS2Fu7d8',
#   'Simple'],
#  ['Column vector - (Lesson 6 of 16 Mathematics Form 2 Topic Vectors I )',
#   'https://www.youtube.com/watch?v=GuXXSrj7r4U',
#   'Simple'],
#  ['Addition of column vectors   - (Lesson 7 of 16 Mathematics Form 2 Topic Vectors I )',
#   'https://www.youtube.com/watch?v=E60rkhIffew',
#   'Simple'],
#  ['Subtraction of column Vectors  - (Lesson 8 of 16 Mathematics Form 2 Topic Vectors I )',
#   'https://www.youtube.com/watch?v=YZif4LMCFDw',
#   'Simple'],
#  ['Multiplication of Column Vector - (Lesson 9 of 16 Mathematics Form 2 Topic Vectors I )',
#   'https://www.youtube.com/watch?v=0Jc9gGXAilo',
#   'Simple'],
#  ['The Position Vector   - (Lesson 10 of 16 Mathematics Form 2 Topic Vectors I )',
#   'https://www.youtube.com/watch?v=-55wnhLysdg',
#   'Simple'],
#  ['Microorganisms Introduction',
#   'https://www.youtube.com/watch?v=sZbRyHOrE9I',
#   'Simple'],
#  ['Microorganisms 02 - Bacteria, the Guys Everywhere',
#   'https://www.youtube.com/watch?v=vff_-xXJ0Zc',
#   'Simple'],
#  ['Microorganisms - Fungi, the Death Lovers',
#   'https://www.youtube.com/watch?v=tw4MvuNyaM0',
#   'Simple'],
#  ['Microorganisms 04 - Creepy Protozoans',
#   'https://www.youtube.com/watch?v=RVZLYc46bzk',
#   'Simple'],
#  ["Microorganisms - Viruses Around Us | Learn from BYJU'S",
#   'https://www.youtube.com/watch?v=_uzHmQdBTBA',
#   'Simple'],
#  ['Tissues', 'https://www.youtube.com/watch?v=pAuKju6eWJI', 'Simple'],
#  ['Summary on Tissues',
#   'https://www.youtube.com/watch?v=fKlsEF9xVUE',
#   'Simple'],
#  ["Introduction to Heredity and Evolution | Learn with BYJU'S",
#   'https://www.youtube.com/watch?v=MqBb44ubESQ',
#   'Simple'],
#  ['Heredity and Evolution - Evolution and Fossil Fuels',
#   'https://www.youtube.com/watch?v=vwnf-x8qHHU',
#   'Simple'],
#  ['Heredity and Evolution - Human Evolution',
#   'https://www.youtube.com/watch?v=P0DQgZSzgyM',
#   'Simple'],
#  ["Structure of Human Ear | Learn with BYJU'S",
#   'https://www.youtube.com/watch?v=MgeSuTAIBKY',
#   'Simple'],
#  ["The Process of Farming | Learn with BYJU'S",
#   'https://www.youtube.com/watch?v=Kxwdt0-wDyo',
#   'Simple'],
#  ['General English for GATE, PSUs, and Placements',
#   'https://www.youtube.com/watch?v=_8gNaALlD5Y',
#   'Simple'],
#  ['Parts of Speech: Nouns',
#   'https://www.youtube.com/watch?v=rEGircBQASI',
#   'Simple'],
#  ['Nouns (Solved Questions)',
#   'https://www.youtube.com/watch?v=8b8Xi0nYJB0',
#   'Simple'],
#  ['Parts of Speech: Pronouns (Part 3)',
#   'https://www.youtube.com/watch?v=GBdZy6TZaNA',
#   'Simple'],
#  ['Pronouns (Solved Questions)',
#   'https://www.youtube.com/watch?v=6KOe1RHK_UQ',
#   'Simple'],
#  ['Articles (Part 1)',
#   'https://www.youtube.com/watch?v=8mWg9Hymg7k',
#   'Simple'],
#  ['Articles (Part 2)',
#   'https://www.youtube.com/watch?v=6El9aRj5AVc',
#   'Simple'],
#  ['Articles (Part 3)',
#   'https://www.youtube.com/watch?v=F5iLg8O7N4o',
#   'Simple'],
#  ['Articles (Part 4)',
#   'https://www.youtube.com/watch?v=bEE1N5hdrj8',
#   'Simple'],
#  ['Articles (Solved Questions)',
#   'https://www.youtube.com/watch?v=UOU9mOIDpGg',
#   'Simple'],
#  ['Adjectives (Part 1)',
#   'https://www.youtube.com/watch?v=BpoHDCo8RU4',
#   'Simple'],
#  ['Adjectives (Part 2)',
#   'https://www.youtube.com/watch?v=Q2VPDMelExs',
#   'Simple'],
#  ['Five Steps to Create a New AI Model',
#   'https://www.youtube.com/watch?v=jcgaNrC4ElU',
#   'Simple'],
#  ['How Large Language Models Work',
#   'https://www.youtube.com/watch?v=5sLYAQS9sWQ',
#   'Simple'],
#  ['Why Are There So Many Foundation Models?',
#   'https://www.youtube.com/watch?v=QPQy7jUpmyA',
#   'Simple'],
#  ['What are Convolutional Neural Networks (CNNs)?',
#   'https://www.youtube.com/watch?v=QzY57FaENXg',
#   'Simple'],
#  ['What are GANs (Generative Adversarial Networks)?',
#   'https://www.youtube.com/watch?v=TpMIssRdhco',
#   'Simple'],
#  ['What are Transformers (Machine Learning Model)?',
#   'https://www.youtube.com/watch?v=ZXiruGOCn9s',
#   'Simple'],
#  ['What is LSTM (Long Short Term Memory)?',
#   'https://www.youtube.com/watch?v=b61DPVFX03I',
#   'Simple'],
#  ['What is NLP (Natural Language Processing)?',
#   'https://www.youtube.com/watch?v=fLvJ8VdHLA0',
#   'Simple'],
#  ['NLP vs NLU vs NLG',
#   'https://www.youtube.com/watch?v=1I6bQ12VxV0',
#   'Simple'],
#  ['What is Random Forest?',
#   'https://www.youtube.com/watch?v=gkXX4h3qYm4',
#   'Simple'],
#  ['What are Autoencoders?',
#   'https://www.youtube.com/watch?v=qiUEgSCyY5o',
#   'Simple'],
#  ['What is a Knowledge Graph?',
#   'https://www.youtube.com/watch?v=y7sXDpffzQQ',
#   'Simple'],
#  ['Mixture vs Pure Substance Grade 10',
#   'https://www.youtube.com/watch?v=TxpKUZpF_BI',
#   'Simple'],
#  ['Homogenous vs Heterogenous Grade 10',
#   'https://www.youtube.com/watch?v=4ZGWxQEYzhI',
#   'Simple'],
#  ['Naming Metal and Non metal Grade 10',
#   'https://www.youtube.com/watch?v=4kr8EIXgMYk',
#   'Simple'],
#  ['Naming Metal and Non metal Grade 10',
#   'https://www.youtube.com/watch?v=AkXIYQusF38',
#   'Simple'],
#  ['Naming Non Metals Grade 10',
#   'https://www.youtube.com/watch?v=GQws_qYdCz8',
#   'Simple'],
#  ['Kinetic Energy Grade 10',
#   'https://www.youtube.com/watch?v=dIQznq0k-gw',
#   'Simple'],
#  ['Isotopes Grade 10 | Part 1',
#   'https://www.youtube.com/watch?v=vgEt7DCYVVo',
#   'Simple'],
#  ['Periodic Table Grade 10',
#   'https://www.youtube.com/watch?v=WRNsXTyeZI0',
#   'Simple'],
#  ['Lewis Diagrams Grade 10',
#   'https://www.youtube.com/watch?v=d2JrfO1mNYU',
#   'Simple'],
#  ['Isotopes Grade 10',
#   'https://www.youtube.com/watch?v=zU8dXfKkVFg',
#   'Simple'],
#  ['Ionisation Energy Grade 10',
#   'https://www.youtube.com/watch?v=VKt_iaAyRyk',
#   'Simple'],
#  ['Are you ready for 5th grade math?',
#   'https://www.youtube.com/watch?v=bdBOVJlHtJE',
#   'Hard'],
#  ['5th Grade Math 1.10, Numerical Expressions from Words',
#   'https://www.youtube.com/watch?v=eQgoDAsUW7Y',
#   'Hard'],
#  ['5th Grade Math 2.7, Interpret the Remainder in Division',
#   'https://www.youtube.com/watch?v=FkRmFMwYcTA',
#   'Hard'],
#  ['5th Grade Math 3.2, Place Value of Decimals, Read/Write Standard, Expanded, Word Forms',
#   'https://www.youtube.com/watch?v=Xbi5aqiRoSU',
#   'Hard'],
#  ['5th Grade Math 3.4, Round Decimals Using Place Value or Place-value Chart',
#   'https://www.youtube.com/watch?v=y-qf_h_LmY0',
#   'Hard'],
#  ['5th Grade Math 3.5, Model Decimal Addition',
#   'https://www.youtube.com/watch?v=HQJ8E5kdgbw',
#   'Hard'],
#  ['5th Grade Math 3.6, Model Decimal Subtraction',
#   'https://www.youtube.com/watch?v=_SbKuvv-Jok',
#   'Hard'],
#  ['5th Grade Math 3.11, Word Problem Solving, Add & Subtract Money',
#   'https://www.youtube.com/watch?v=MOlyYI6YdH0',
#   'Hard'],
#  ['5th Grade Math 4.6, Model Decimal by Decimal Multiplication',
#   'https://www.youtube.com/watch?v=bVxUqES_-LY',
#   'Hard'],
#  ['5th Grade Math 5.2, Model Dividing Decimals by Whole Numbers',
#   'https://www.youtube.com/watch?v=yIx-yi23Kro',
#   'Hard'],
#  ['5th Grade Math 5.3, Estimate Decimal Quotients',
#   'https://www.youtube.com/watch?v=Jsu0HRcC40k',
#   'Hard'],
#  ['5th Grade Math 5.5, Model Dividing a Decimal by a Decimal',
#   'https://www.youtube.com/watch?v=NM3jjQfAGJs',
#   'Hard'],
#  ['5th Grade Math 6.2, Model Subtraction with Unlike Denominators',
#   'https://www.youtube.com/watch?v=dtGI9E5_0_o',
#   'Hard'],
#  ['5th Grade Math 6.10, Use Properties of Addition to Add Fractions',
#   'https://www.youtube.com/watch?v=i5QmUTkD-cQ',
#   'Hard'],
#  ['5th Grade Math 7.1, Find a Fractional Part of a Group',
#   'https://www.youtube.com/watch?v=7ecCApEIoHI',
#   'Hard'],
#  ['5th Grade Math 7.2, Model Multiplying Fractions & Whole Numbers',
#   'https://www.youtube.com/watch?v=bcB7EKRqP9A',
#   'Hard'],
#  ['5th Grade Math 7.5, Compare Fraction Factors & Products',
#   'https://www.youtube.com/watch?v=ntQDtwr12tE',
#   'Hard'],
#  ['5th Grade Math 7.9, Multiply Mixed Numbers',
#   'https://www.youtube.com/watch?v=lj6ApYHiaWg',
#   'Hard'],
#  ['5th Grade Math 8.1, Model to Divide Fractions and Whole Numbers',
#   'https://www.youtube.com/watch?v=BA0kznlaVFY',
#   'Hard'],
#  ['5th Grade Math 8.2, Word Problem Solving, Use Multiplication for Fraction Division',
#   'https://www.youtube.com/watch?v=bi2CLSuTmcs',
#   'Hard'],
#  ['Moving Coil-Meter & Earpieces - (Lesson 17 of 17 -Physics Form 2 - Topic 6)',
#   'https://www.youtube.com/watch?v=RdqYqgyaiwI',
#   'Hard'],
#  ['Magnetic Tape Pick Recorder & Moving Coil Loudspeaker -(Lesson 16 of 17 -Physics Form 2 Topic 6)',
#   'https://www.youtube.com/watch?v=UNIQ14Fyjjs',
#   'Hard'],
#  ['Magnetic Relay & Circuit Breakers -(Lesson 15 of 17 -Physics Form 2 - Topic 6)',
#   'https://www.youtube.com/watch?v=izeby2uBVAk',
#   'Hard'],
#  ['A Simple DC Motor -(Lesson 14 of 17 -Physics Form 2 -Topic Magnetic Effect of an Electric Current)',
#   'https://www.youtube.com/watch?v=dHQ1BFuFmxM',
#   'Hard'],
#  ['Simple Electromagnet - (Lesson 7 of 17 - Physics Form 2 - T6 Magnetic Effect of an Electric Current)',
#   'https://www.youtube.com/watch?v=IWQMvcq1yv0',
#   'Hard'],
#  ["Children's Songs Lesson 1 - English Form 4 -Topic 4- Oral Poetry- KCSE Lesson Notes & Videos",
#   'https://www.youtube.com/watch?v=THyQ8iJZFck',
#   'Hard'],
#  ['Oral Poetry -War Poetry Lesson 5 -English Form 4- Topic Oral Poetry- KCSE Lesson Notes & Videos',
#   'https://www.youtube.com/watch?v=ghuuJNusnWE',
#   'Hard'],
#  ['Oral Poetry - Lullabies Lesson 3- English Form 4- Topic Oral Poetry- KCSE Lesson Notes & Videos',
#   'https://www.youtube.com/watch?v=5X9VPVt29ks',
#   'Hard'],
#  ['A TEST OF WISDOM 😉|| EXPLANATION || GRADE 4 || ENGLISH',
#   'https://www.youtube.com/watch?v=qg7kfYGJ33s',
#   'Hard'],
#  ['POEM -ALL THINGS BRIGHT 🌞 AND BEAUTIFUL ❤️ || EXPLAINATION || GRADE 4',
#   'https://www.youtube.com/watch?v=eyNj6UGFMB4',
#   'Hard'],
#  ['THE FLATTERED FLYING \U0001fabd FISH🐟 || ENGLISH POEM || SUMMARY || Empowering English || Grade 4',
#   'https://www.youtube.com/watch?v=h3yrPbid43s',
#   'Hard'],
#  ['INCREDIBLE SOUTH AMERICA || REFERENCE GUIDE || GRADE 4 ||  EMPOWERING ENGLISH',
#   'https://www.youtube.com/watch?v=1UYGhBT9urQ',
#   'Hard'],
#  ['MY AUNT - POEM || REFERENCE GUIDE || ICSE || GRADE 4 || ENGLISH',
#   'https://www.youtube.com/watch?v=Zu2nq9_sA_U',
#   'Hard'],
#  ['POEM - THE OLD WIFE AND THE GHOST || REFERENCE GUIDE || GRADE 4 || ENGLISH',
#   'https://www.youtube.com/watch?v=yE4nEpP5XlU',
#   'Hard'],
#  ['SPIES || REFERENCE GUIDE || ENGLISH || GRADE 4',
#   'https://www.youtube.com/watch?v=qVlF00t1SmQ',
#   'Hard'],
#  ['“POEM – COLONEL FAZACKERLY” || REFERENCE GUIDE || GRADE 4 || ENGLISH || ICSE',
#   'https://www.youtube.com/watch?v=Hd2CqfXkNEQ',
#   'Hard'],
#  ['“Poem – The Blind Boy ”|| Reference Guide || Class 4 || ICSE || English',
#   'https://www.youtube.com/watch?v=IBdaVasXf3g',
#   'Hard'],
#  ['“Chapter –  Ruins in the Forest ” || Reference Guide || Grade 4 || Empowring English || ICSE',
#   'https://www.youtube.com/watch?v=H9dp2kj2ffA',
#   'Hard'],
#  ['“Chapter – The Sea Storm”|| Reference Guide || Empowering English || Grade 4 || ICSE',
#   'https://www.youtube.com/watch?v=JTePlo1_xrw',
#   'Hard'],
#  ['“Chapter – Pandora’s Box”|| Empowering English || Grade 4 || ICSE',
#   'https://www.youtube.com/watch?v=qrHOrYak3xc',
#   'Hard'],
#  ['“Chapter – Finding the Wood”|| Reference Guide || Grade 4 || Empowering English || ICSE',
#   'https://www.youtube.com/watch?v=FCpKxXzP4nY',
#   'Hard'],
#  ['“Chapter – Mrs. Twit”|| Reference Guide || Grade 4 || Empowering English || ICSE',
#   'https://www.youtube.com/watch?v=OJEEHLKFqTU',
#   'Hard'],
#  ['“Poem – Louder than a clap of Thunder”|| Reference Guide || Empowering English || Grade 4 || ICSE',
#   'https://www.youtube.com/watch?v=WCxwnwBaHAs',
#   'Hard'],
#  ['“Poem – Flint”|| Reference Guide || ICSE || Empowering English || Grade 4',
#   'https://www.youtube.com/watch?v=h-nYNXfNqzE',
#   'Hard'],
#  ['“Chapter – The Magic Bowl”|| Reference Guide || ICSE || Grade 4 || Empowering English',
#   'https://www.youtube.com/watch?v=YdklnHUqvw4',
#   'Hard'],
#  ['“Poem – The Cruel Naughty Boy”|| Empowering English || Grade 4 || ICSE',
#   'https://www.youtube.com/watch?v=3RpLhmciXuE',
#   'Hard'],
#  ['“Poem – Godfrey Gordon Gustavus Gore”|| Reference Guide || Grade 4 || ICSE || Empowering English',
#   'https://www.youtube.com/watch?v=L2Wi_SRa1Ws',
#   'Hard'],
#  ['“Poem – An Irish Airman Foresees His Death”|| Magic Lantern || Class 7 || English || ICSE || CBSE',
#   'https://www.youtube.com/watch?v=X_Vdsqqt6Jg',
#   'Hard'],
#  ['“Chapter 12 – Huck and Jim Escape”|| English || Magic Lantern || Grade 7 || ICSE || CBSE',
#   'https://www.youtube.com/watch?v=CFob4wPisgA',
#   'Hard'],
#  ['“Chapter 11 – Malala =The girl who spoke out”|| English || Magic Lantern || Grade 7 || ICSE || CBSE',
#   'https://www.youtube.com/watch?v=pTa6Q7aizNc',
#   'Hard'],
#  ['“Chapter 10 – Little Brother”|| Magic Lantern || Grade 7 || ICSE || CBSE || English',
#   'https://www.youtube.com/watch?v=NLT9LGTQzQQ',
#   'Hard'],
#  ['“Poem – India’s Pride”|| ICSE || CBSE || Grade 7 || Magic Lantern || English',
#   'https://www.youtube.com/watch?v=a2UfamERrE8',
#   'Hard'],
#  ['“Chapter 9 – Corvus, The Intelligent Crow”|| English || Magic Lantern || Grade 7 || ICSE || CBSE',
#   'https://www.youtube.com/watch?v=5LUoVHGHW5o',
#   'Hard'],
#  ['"Chapter 8 – The Ways of the Jungle”|| Grade 7 || Magic Lantern || CBSE || ICSE || English',
#   'https://www.youtube.com/watch?v=_bnNG1-tiJ0',
#   'Hard'],
#  ['“Poem – The Tyger”|| Magic Lantern || Grade 7 || ICSE || CBSE || English',
#   'https://www.youtube.com/watch?v=aqe1hBBstaw',
#   'Hard'],
#  ['“Chapter 7 – My School Days”|| Magic Lantern || CBSE || ICSE || Class 7 || English',
#   'https://www.youtube.com/watch?v=0OnqUl9TEds',
#   'Hard'],
#  ['“Poem – If Only I Were”|| Magic Lantern || CBSE || ICSE || English || Grade 7',
#   'https://www.youtube.com/watch?v=TjD9Wn-tQ4A',
#   'Hard'],
#  ['Local Self - Government In Urban Areas: Municipal Bodies || Reference Guide || HISTORY & CIVICS',
#   'https://www.youtube.com/watch?v=KiuM_Rl_r8s',
#   'Hard'],
#  ['“Chapter 9 – The Rise of Magadha”|| Reference Guide || Grade 6 || History & Civics || ICSE',
#   'https://www.youtube.com/watch?v=N8BtUZ8-3y4',
#   'Hard'],
#  ['“Ch.8 – Mahavira & Buddha– Great Preachers”|| ICSE || CBSE || Grade 6 || History & Civics',
#   'https://www.youtube.com/watch?v=aJvlfi7F-Xw',
#   'Hard'],
#  ['“Ch.7 – The Vedic Age” || Grade 6 || History & Civics || CBSE || ICSE',
#   'https://www.youtube.com/watch?v=igASGXSx8KY',
#   'Hard'],
#  ['ICT Grade 10 (English Medium) Chapter 1 - (Part 1) -Information and Communication Technology',
#   'https://www.youtube.com/watch?v=HndOJzDpIvY',
#   'Hard'],
#  ['ICT Grade 10 (English Medium) Chapter 1 - (Part 2) -Information and Communication Technology',
#   'https://www.youtube.com/watch?v=78n4DdD4vtc',
#   'Hard'],
#  ['ICT (English medium)- Grade 10 Chapter 2 - (Part 3) -Fundamentals of a computer system.',
#   'https://www.youtube.com/watch?v=dANnzmxhlDE',
#   'Hard'],
#  ['An Artist of the Floating World Characters and Characterization Episode 4 | EasyElimu',
#   'https://www.youtube.com/watch?v=KHQOgRf2oVA',
#   'Hard'],
#  ['Language and Style in Episode 2 of An Artist of the Floating World | EasyElimu',
#   'https://www.youtube.com/watch?v=wfXwvXEj3RY',
#   'Hard'],
#  ['Language and Style in Episode 3 of An Artist of the Floating World | EasyElimu',
#   'https://www.youtube.com/watch?v=mr3_1Sg7hRY',
#   'Hard'],
#  ['The Changing Values in Japan and Intergenerational conflicts in An Artist of the Floating World',
#   'https://www.youtube.com/watch?v=oMZKjA6rauo',
#   'Hard'],
#  ['Themes of Disillusionment and Pessimism and Loss and Grief in An Artist of the Floating World',
#   'https://www.youtube.com/watch?v=gmsf3mc53ok',
#   'Hard'],
#  ['Theme of Marriage Negotiations in An Artist of the Floating World | EasyElimu',
#   'https://www.youtube.com/watch?v=D9UqUgzUmqU',
#   'Hard'],
#  ['Themes of Admiration, Satisfaction and Reassurance; and Religion in An Artist of the Floating World',
#   'https://www.youtube.com/watch?v=iLTOU3INkkQ',
#   'Hard'],
#  ['Themes of Hope and Optimism; and Identity in An Artist of the Floating World | EasyElimu',
#   'https://www.youtube.com/watch?v=U2CQbGWnje4',
#   'Hard'],
#  ['Theme of Politicization of Art and Imperialism in An Artist of the Floating World | EasyElimu',
#   'https://www.youtube.com/watch?v=e-bsMyqa5OM',
#   'Hard'],
#  ['Parliament of Owls Act 4 Plot Summary - EasyElimu',
#   'https://www.youtube.com/watch?v=ZglTnYjN5vk',
#   'Hard'],
#  ['Parliament of Owls Theme 5 of 9: Monarchy - EasyElimu',
#   'https://www.youtube.com/watch?v=uZVd5ozJUUQ',
#   'Hard'],
#  ['Parliament of Owls Theme 9 of 9: Corruption and Bribery - EasyElimu',
#   'https://www.youtube.com/watch?v=W3A3KYmnmyw',
#   'Hard'],
#  ['Stylistic Devices (Language and Style) in Act 3 of Parliament of Owls - EasyElimu',
#   'https://www.youtube.com/watch?v=Vka-AeAp6EM',
#   'Hard'],
#  ['Stylistic Devices (Language and Style) in Act 4 of Parliament of Owls - EasyElimu',
#   'https://www.youtube.com/watch?v=zfGJ7bsNxt0',
#   'Hard'],
#  ['What Do Various Nutrients Do for Our Body - Components of Food | Class 6 Science Chapter 1',
#   'https://www.youtube.com/watch?v=BXwJ1ACPPk8',
#   'Hard'],
#  ['Loss of Nutrients and Balanced Diet - Components of Food | Class 6 Science Chapter 1',
#   'https://www.youtube.com/watch?v=HJlWxUZ4QWU',
#   'Hard'],
#  ['Frequently Asked Questions - Components of Food | Class 6 Science Chapter 1',
#   'https://www.youtube.com/watch?v=S6xeZKjYWBs',
#   'Hard'],
#  ['Frequently Asked Questions - Sorting Materials Into Groups | Class 6 Science Chapter 2',
#   'https://www.youtube.com/watch?v=DhXSwmFAo50',
#   'Hard'],
#  ['Separation of Mixtures - Separation of Substance | Class 6 Science Chapter 3',
#   'https://www.youtube.com/watch?v=VGKohJWEBmU',
#   'Hard'],
#  ['Frequently Asked Questions - Seperation of Substance | Class 6 Science Chapter 3',
#   'https://www.youtube.com/watch?v=dgEfoReeVZU',
#   'Hard'],
#  ['Types of Roots - Getting to know Plants (Activity 3 and 4) | Class 6 Science Chapter 4',
#   'https://www.youtube.com/watch?v=uOKCkBnyZCU',
#   'Hard'],
#  ['Parts of a Flower - Getting to Know Plants | Class 6 Science Chapter 4',
#   'https://www.youtube.com/watch?v=BZIGEOX8jms',
#   'Hard'],
#  ['Frequently Asked Questions - Getting to Know Plants | Class 6 Science Chapter 4',
#   'https://www.youtube.com/watch?v=oiuTtzMU_k0',
#   'Hard'],
#  ['Different Types of Joints - Body Movement | Class 6 Science Chapter 5',
#   'https://www.youtube.com/watch?v=fcTu-py3fqM',
#   'Hard'],
#  ['Frequently Asked Question - Body Movements | Class 6 Science Chapter 5 | CBSE 2024-25',
#   'https://www.youtube.com/watch?v=q_Ya9b8RIsg',
#   'Hard'],
#  ['Habitat and Adaptation - The Living Organisms Characteristics & Habitats | Class 6 Science Chapter 6',
#   'https://www.youtube.com/watch?v=X0jpymLKxQY',
#   'Hard'],
#  ['Journey Through Different Habitat-The Living Organisms Characteristics & Habitats | Class 6 Science',
#   'https://www.youtube.com/watch?v=MNleMIhKjNc',
#   'Hard'],
#  ['The Living Organisms Characteristics & Habitats - FAQs | Class 6 Science Ch6 | CBSE 2024-25',
#   'https://www.youtube.com/watch?v=3c_dTtx7ob8',
#   'Hard'],
#  ['Types Of Motion - Motion and Measurement of Distances | Class 6 Science Chapter 7 |',
#   'https://www.youtube.com/watch?v=3A4ZYLI-XDg',
#   'Hard'],
#  ['Frequently Asked Questions - Motion and Measurement of Distances | Class 6 Science Chapter 7 |',
#   'https://www.youtube.com/watch?v=jiwhVLgOdc0',
#   'Hard'],
#  ['Introduction - Lights, Shadows and Reflections - | Class 6 Science Chapter 8',
#   'https://www.youtube.com/watch?v=3bOJfnCVFsk',
#   'Hard'],
#  ['Pinhole Camera - Lights, Shadows and Reflections | Class 6 Science Chapter 8 |',
#   'https://www.youtube.com/watch?v=McZV5VhFn-Y',
#   'Hard'],
#  ['Reflection and Mirrors - Lights, Shadows and Reflections | Class 6 Science Chapter 8 | CBSE 2024-25',
#   'https://www.youtube.com/watch?v=TrsIAqYDl2s',
#   'Hard'],
#  ['Cell and battery - Electricity and Circuits | Class 6 Science Chapter 9',
#   'https://www.youtube.com/watch?v=2w6BWn5y-sY',
#   'Hard']]

# %%
# total number of urls extracted from all the playlists
len(data)
# Out:
# 193

# %%
# create a dataframe to store the extracted video names, urls, and class
video_df = pd.DataFrame(data, columns=['Video Name', 'Video URL', 'Complexity Level'])

# %%
# number of video urls in each class (Simple, Hard)
video_df['Complexity Level'].value_counts()
# Out:
# Hard      98
# Simple    95
# Name: Complexity Level, dtype: int64

# %%
video_df.to_csv('presentation_complexity_dataset_weak_annotation.csv', index=False)

# %% [markdown]
# ## Dataset Preparation for Manual Re-Annotation and Verification

# %%
pcd_weak_df = pd.read_csv('presentation_complexity_dataset_weak_annotation.csv')
pcd_weak_df.head()
# Out:
#                              Video Name  \
# 0    Plant Parts and Functions for Kids
# 1  Adjectives for Kids | Homeschool Pop
# 2               Roman Numerals For Kids
# 3            Benjamin Franklin for Kids
# 4                  Paul Revere for Kids
#
#                                      Video URL Complexity Level
# 0  https://www.youtube.com/watch?v=18amLZ9vfG8           Simple
# 1  https://www.youtube.com/watch?v=4jxXnHSbicY           Simple
# 2  https://www.youtube.com/watch?v=NrnXsKYpLJM           Simple
# 3  https://www.youtube.com/watch?v=5LcMXnZfFFY           Simple
# 4  https://www.youtube.com/watch?v=dmwcfaythY4           Simple

# %%
# drop 'Complexity Level' class column to avoid the influence of these labels during manual re-annotation
modified_pcd_df = pcd_weak_df.drop('Complexity Level', axis=1)
modified_pcd_df.head()
# Out:
#                              Video Name  \
# 0    Plant Parts and Functions for Kids
# 1  Adjectives for Kids | Homeschool Pop
# 2               Roman Numerals For Kids
# 3            Benjamin Franklin for Kids
# 4                  Paul Revere for Kids
#
#                                      Video URL
# 0  https://www.youtube.com/watch?v=18amLZ9vfG8
# 1  https://www.youtube.com/watch?v=4jxXnHSbicY
# 2  https://www.youtube.com/watch?v=NrnXsKYpLJM
# 3  https://www.youtube.com/watch?v=5LcMXnZfFFY
# 4  https://www.youtube.com/watch?v=dmwcfaythY4

# %%
# shuffle the samples in the dataset to ensure fair labelling is performed
modified_pcd_df = modified_pcd_df.sample(n=len(pcd_weak_df), replace=False)
modified_pcd_df
# Out:
#                                             Video Name  \
# 114  5th Grade Math 8.2, Word Problem Solving, Use ...
# 14    Ancient Greece for Kids | History Learning Video
# 18       Ancient Mesopotamia 101 | National Geographic
# 121  Oral Poetry -War Poetry Lesson 5 -English Form...
# 74            Why Are There So Many Foundation Models?
# ..                                                 ...
# 22   Lesson 3 - Finding Factors Of Numbers - (5th G...
# 128  POEM - THE OLD WIFE AND THE GHOST || REFERENCE...
# 143  “Chapter 12 – Huck and Jim Escape”|| English |...
# 71                                 Adjectives (Part 2)
# 93                                   Isotopes Grade 10
#
#                                        Video URL
# 114  https://www.youtube.com/watch?v=bi2CLSuTmcs
# 14   https://www.youtube.com/watch?v=jloEzVh31TE
# 18   https://www.youtube.com/watch?v=xVf5kZA0HtQ
# 121  https://www.youtube.com/watch?v=ghuuJNusnWE
# 74   https://www.youtube.com/watch?v=QPQy7jUpmyA
# ..                                           ...
# 22   https://www.youtube.com/watch?v=OWlvooseo_o
# 128  https://www.youtube.com/watch?v=yE4nEpP5XlU
# 143  https://www.youtube.com/watch?v=CFob4wPisgA
# 71   https://www.youtube.com/watch?v=Q2VPDMelExs
# 93   https://www.youtube.com/watch?v=zU8dXfKkVFg
#
# [193 rows x 2 columns]

# %%
# name the index column
# index column will be used later to sort the dataset and compare the manual labels with the weak labels
modified_pcd_df.index.name = 'ID'
modified_pcd_df
# Out:
#                                             Video Name  \
# ID
# 114  5th Grade Math 8.2, Word Problem Solving, Use ...
# 14    Ancient Greece for Kids | History Learning Video
# 18       Ancient Mesopotamia 101 | National Geographic
# 121  Oral Poetry -War Poetry Lesson 5 -English Form...
# 74            Why Are There So Many Foundation Models?
# ..                                                 ...
# 22   Lesson 3 - Finding Factors Of Numbers - (5th G...
# 128  POEM - THE OLD WIFE AND THE GHOST || REFERENCE...
# 143  “Chapter 12 – Huck and Jim Escape”|| English |...
# 71                                 Adjectives (Part 2)
# 93                                   Isotopes Grade 10
#
#                                        Video URL
# ID
# 114  https://www.youtube.com/watch?v=bi2CLSuTmcs
# 14   https://www.youtube.com/watch?v=jloEzVh31TE
# 18   https://www.youtube.com/watch?v=xVf5kZA0HtQ
# 121  https://www.youtube.com/watch?v=ghuuJNusnWE
# 74   https://www.youtube.com/watch?v=QPQy7jUpmyA
# ..                                           ...
# 22   https://www.youtube.com/watch?v=OWlvooseo_o
# 128  https://www.youtube.com/watch?v=yE4nEpP5XlU
# 143  https://www.youtube.com/watch?v=CFob4wPisgA
# 71   https://www.youtube.com/watch?v=Q2VPDMelExs
# 93   https://www.youtube.com/watch?v=zU8dXfKkVFg
#
# [193 rows x 2 columns]

# %%
modified_pcd_df.to_csv('modified_pcd_for_manual_annotation.csv')

# %% [markdown]
# ## Dataset Finalization After Manual Re-Annotation and Verification

# %%
# load the verified manually annotated dataset
mpcd_checked_df = pd.read_csv('modified_pcd_for_manual_annotation_checked.csv', index_col='ID')
mpcd_checked_df.head()
# Out:
#                                             Video Name  \
# ID
# 114  5th Grade Math 8.2, Word Problem Solving, Use ...
# 14    Ancient Greece for Kids | History Learning Video
# 18       Ancient Mesopotamia 101 | National Geographic
# 121  Oral Poetry -War Poetry Lesson 5 -English Form...
# 74            Why Are There So Many Foundation Models?
#
#                                        Video URL Manual Complexity Level
# ID
# 114  https://www.youtube.com/watch?v=bi2CLSuTmcs                    hard
# 14   https://www.youtube.com/watch?v=jloEzVh31TE                  simple
# 18   https://www.youtube.com/watch?v=xVf5kZA0HtQ                  simple
# 121  https://www.youtube.com/watch?v=ghuuJNusnWE                    hard
# 74   https://www.youtube.com/watch?v=QPQy7jUpmyA                  simple

# %%
# load the weakly annotated dataset which was annotated based on the playlist complexity level estimation
pcd_weak_df = pd.read_csv('presentation_complexity_dataset_weak_annotation.csv')
pcd_weak_df.head()
# Out:
#                              Video Name  \
# 0    Plant Parts and Functions for Kids
# 1  Adjectives for Kids | Homeschool Pop
# 2               Roman Numerals For Kids
# 3            Benjamin Franklin for Kids
# 4                  Paul Revere for Kids
#
#                                      Video URL Complexity Level
# 0  https://www.youtube.com/watch?v=18amLZ9vfG8           Simple
# 1  https://www.youtube.com/watch?v=4jxXnHSbicY           Simple
# 2  https://www.youtube.com/watch?v=NrnXsKYpLJM           Simple
# 3  https://www.youtube.com/watch?v=5LcMXnZfFFY           Simple
# 4  https://www.youtube.com/watch?v=dmwcfaythY4           Simple

# %%
# sort the manually annotated dataset in ascending order of column 'ID' which is the index column
# dataset was shuffled for manual re-annotation and verification to ensure fair labelling was performed
mpcd_checked_df.sort_index(inplace=True)
mpcd_checked_df.head()
# Out:
#                               Video Name  \
# ID
# 0     Plant Parts and Functions for Kids
# 1   Adjectives for Kids | Homeschool Pop
# 2                Roman Numerals For Kids
# 3             Benjamin Franklin for Kids
# 4                   Paul Revere for Kids
#
#                                       Video URL Manual Complexity Level
# ID
# 0   https://www.youtube.com/watch?v=18amLZ9vfG8                  simple
# 1   https://www.youtube.com/watch?v=4jxXnHSbicY                  simple
# 2   https://www.youtube.com/watch?v=NrnXsKYpLJM                  simple
# 3   https://www.youtube.com/watch?v=5LcMXnZfFFY                  simple
# 4   https://www.youtube.com/watch?v=dmwcfaythY4                  simple

# %%
# video urls that we planned to remove during the manual re-annotation phase were labelled with n/a
# these urls are now labelled as nan (missing values) by Pandas
mpcd_checked_df['Manual Complexity Level'].unique()
# Out:
# array(['simple', nan, 'hard'], dtype=object)

# %%
mpcd_checked_df.isnull().sum()
# Out:
# Video Name                  0
# Video URL                   0
# Manual Complexity Level    22
# dtype: int64

# %%
# get the indices of rows with missing values from the manually annotated dataset
missing_value_indices = mpcd_checked_df[mpcd_checked_df.isnull().any(axis=1)].index
missing_value_indices
# Out:
# Int64Index([ 46,  84, 106, 173, 174, 175, 176, 177, 178, 179, 180, 181, 182,
#             183, 184, 185, 186, 187, 188, 190, 191, 192],
#            dtype='int64', name='ID')

# %%
# remove the video urls with missing complexity level from the manually annotated dataset
mpcd_checked_df.drop(index=missing_value_indices, inplace=True)

# %%
mpcd_checked_df.isnull().sum()
# Out:
# Video Name                 0
# Video URL                  0
# Manual Complexity Level    0
# dtype: int64

# %%
# remove the video urls with missing complexity level (in the manually annotated dataset) from the weakly annotated dataset
pcd_weak_df.drop(index=missing_value_indices, inplace=True)

# %%
# convert the weakly annotated labels to lowercase to match the casing of the manually annotated labels
pcd_weak_df['Complexity Level'] = pcd_weak_df['Complexity Level'].str.lower()

# %%
# compare the weakly annotated labels with the manually annotated labels to check if there is a large deviation from the initial estimation
(mpcd_checked_df['Manual Complexity Level'] == pcd_weak_df['Complexity Level']).value_counts()
# Out:
# True     170
# False      1
# dtype: int64

# %%
# manually annotated dataset has a class ratio of 1.2:1 which is almost balanced
mpcd_checked_df['Manual Complexity Level'].value_counts()
# Out:
# simple    94
# hard      77
# Name: Manual Complexity Level, dtype: int64

# %%
# rename the class column in the manually annotated dataset
mpcd_checked_df.rename({'Manual Complexity Level':'Complexity Level'}, axis=1, inplace=True)
mpcd_checked_df.columns
# Out:
# Index(['Video Name', 'Video URL', 'Complexity Level'], dtype='object')

# %%
mpcd_checked_df.to_csv('presentation_complexity_dataset.csv', index=False)

# %% [markdown]
# ## Downloading YouTube Videos in the Dataset

# %%
# download YouTube video using url in 'mp4' file format with the highest resolution
def download_video(n, url, save_path):
    try:
        is_name_changed = False
        
        video_object = yt(url)
        video_stream = video_object.streams.filter(file_extension='mp4').get_highest_resolution()
        
        video_filename = video_stream.default_filename
        video_path = os.path.join(save_path, video_filename)
        
        # change the name of the file to the same name with a number at the end if it has the same name as an existing file
        if os.path.exists(video_path):
            i = 1
            
            video_name, extension = os.path.splitext(video_filename)
            video_filename = f'{video_name}_{i}{extension}'
            video_path = os.path.join(save_path, video_filename)
            
            while os.path.exists(video_path):
                i += 1
                
                video_filename = f'{video_name}_{i}{extension}'
                video_path = os.path.join(save_path, video_filename)
            
            is_name_changed = True
            
            video_stream.download(output_path=save_path, filename=video_filename)
        else:
            video_stream.download(output_path=save_path)
        
        print(f"Video {n}: Downloaded successfully")
        
        return is_name_changed, video_filename
    except:
        print(f"Video {n}: Error occurred")

# %%
pcd_df = pd.read_csv('presentation_complexity_dataset.csv')
pcd_df.head()
# Out:
#                              Video Name  \
# 0    Plant Parts and Functions for Kids
# 1  Adjectives for Kids | Homeschool Pop
# 2               Roman Numerals For Kids
# 3            Benjamin Franklin for Kids
# 4                  Paul Revere for Kids
#
#                                      Video URL Complexity Level
# 0  https://www.youtube.com/watch?v=18amLZ9vfG8           simple
# 1  https://www.youtube.com/watch?v=4jxXnHSbicY           simple
# 2  https://www.youtube.com/watch?v=NrnXsKYpLJM           simple
# 3  https://www.youtube.com/watch?v=5LcMXnZfFFY           simple
# 4  https://www.youtube.com/watch?v=dmwcfaythY4           simple

# %%
# extract the urls of the videos in the 'simple' class from the presentation complexity dataset
simple_video_urls = list(pcd_df.loc[pcd_df['Complexity Level'] == 'simple', 'Video URL'])
simple_video_urls
# Out:
# ['https://www.youtube.com/watch?v=18amLZ9vfG8',
#  'https://www.youtube.com/watch?v=4jxXnHSbicY',
#  'https://www.youtube.com/watch?v=NrnXsKYpLJM',
#  'https://www.youtube.com/watch?v=5LcMXnZfFFY',
#  'https://www.youtube.com/watch?v=dmwcfaythY4',
#  'https://www.youtube.com/watch?v=uL_6b-k7aVI',
#  'https://www.youtube.com/watch?v=Pxt_uA8w-t4',
#  'https://www.youtube.com/watch?v=v23V-cHPpz4',
#  'https://www.youtube.com/watch?v=X9Xyw43cC7M',
#  'https://www.youtube.com/watch?v=wMMwBhkxBv0',
#  'https://www.youtube.com/watch?v=YRxNQPmj1-8',
#  'https://www.youtube.com/watch?v=Jd4kD9TicbA',
#  'https://www.youtube.com/watch?v=IAQAAJo1fI0',
#  'https://www.youtube.com/watch?v=J2exRx5QMRU',
#  'https://www.youtube.com/watch?v=jloEzVh31TE',
#  'https://www.youtube.com/watch?v=lBYmOuajdC8',
#  'https://www.youtube.com/watch?v=hO1tzmi1V5g',
#  'https://www.youtube.com/watch?v=n7ndRwqJYDM',
#  'https://www.youtube.com/watch?v=xVf5kZA0HtQ',
#  'https://www.youtube.com/watch?v=KhDY4KJuvc0',
#  'https://www.youtube.com/watch?v=xlK8Smp5Ug8',
#  'https://www.youtube.com/watch?v=SKEmIj-YCPc',
#  'https://www.youtube.com/watch?v=OWlvooseo_o',
#  'https://www.youtube.com/watch?v=U0-sgUCXHxA',
#  'https://www.youtube.com/watch?v=2hWAL_HERag',
#  'https://www.youtube.com/watch?v=R68uRLRJssA',
#  'https://www.youtube.com/watch?v=vzUaMZd5IeU',
#  'https://www.youtube.com/watch?v=vxth4e33HUU',
#  'https://www.youtube.com/watch?v=7TgsXK0ZUu8',
#  'https://www.youtube.com/watch?v=ZfO4TzfcTc0',
#  'https://www.youtube.com/watch?v=LDqQ9y5ILEc',
#  'https://www.youtube.com/watch?v=xOHGaNF0tIg',
#  'https://www.youtube.com/watch?v=ZEF9mnL9_W0',
#  'https://www.youtube.com/watch?v=c6vUNJzoON0',
#  'https://www.youtube.com/watch?v=ksLh67GPBTc',
#  'https://www.youtube.com/watch?v=9AIBnaow5a0',
#  'https://www.youtube.com/watch?v=IZoIvJEiNaM',
#  'https://www.youtube.com/watch?v=wAPpAxfsars',
#  'https://www.youtube.com/watch?v=ImkN3lC36vA',
#  'https://www.youtube.com/watch?v=nuAA9OEINGc',
#  'https://www.youtube.com/watch?v=tngxz1Jr3ME',
#  'https://www.youtube.com/watch?v=AKTvZCjowT4',
#  'https://www.youtube.com/watch?v=CvUiS2Fu7d8',
#  'https://www.youtube.com/watch?v=GuXXSrj7r4U',
#  'https://www.youtube.com/watch?v=E60rkhIffew',
#  'https://www.youtube.com/watch?v=YZif4LMCFDw',
#  'https://www.youtube.com/watch?v=-55wnhLysdg',
#  'https://www.youtube.com/watch?v=sZbRyHOrE9I',
#  'https://www.youtube.com/watch?v=vff_-xXJ0Zc',
#  'https://www.youtube.com/watch?v=tw4MvuNyaM0',
#  'https://www.youtube.com/watch?v=RVZLYc46bzk',
#  'https://www.youtube.com/watch?v=_uzHmQdBTBA',
#  'https://www.youtube.com/watch?v=pAuKju6eWJI',
#  'https://www.youtube.com/watch?v=fKlsEF9xVUE',
#  'https://www.youtube.com/watch?v=MqBb44ubESQ',
#  'https://www.youtube.com/watch?v=vwnf-x8qHHU',
#  'https://www.youtube.com/watch?v=P0DQgZSzgyM',
#  'https://www.youtube.com/watch?v=MgeSuTAIBKY',
#  'https://www.youtube.com/watch?v=Kxwdt0-wDyo',
#  'https://www.youtube.com/watch?v=_8gNaALlD5Y',
#  'https://www.youtube.com/watch?v=rEGircBQASI',
#  'https://www.youtube.com/watch?v=8b8Xi0nYJB0',
#  'https://www.youtube.com/watch?v=GBdZy6TZaNA',
#  'https://www.youtube.com/watch?v=6KOe1RHK_UQ',
#  'https://www.youtube.com/watch?v=8mWg9Hymg7k',
#  'https://www.youtube.com/watch?v=6El9aRj5AVc',
#  'https://www.youtube.com/watch?v=F5iLg8O7N4o',
#  'https://www.youtube.com/watch?v=bEE1N5hdrj8',
#  'https://www.youtube.com/watch?v=UOU9mOIDpGg',
#  'https://www.youtube.com/watch?v=BpoHDCo8RU4',
#  'https://www.youtube.com/watch?v=Q2VPDMelExs',
#  'https://www.youtube.com/watch?v=jcgaNrC4ElU',
#  'https://www.youtube.com/watch?v=5sLYAQS9sWQ',
#  'https://www.youtube.com/watch?v=QPQy7jUpmyA',
#  'https://www.youtube.com/watch?v=QzY57FaENXg',
#  'https://www.youtube.com/watch?v=TpMIssRdhco',
#  'https://www.youtube.com/watch?v=ZXiruGOCn9s',
#  'https://www.youtube.com/watch?v=b61DPVFX03I',
#  'https://www.youtube.com/watch?v=fLvJ8VdHLA0',
#  'https://www.youtube.com/watch?v=1I6bQ12VxV0',
#  'https://www.youtube.com/watch?v=gkXX4h3qYm4',
#  'https://www.youtube.com/watch?v=qiUEgSCyY5o',
#  'https://www.youtube.com/watch?v=y7sXDpffzQQ',
#  'https://www.youtube.com/watch?v=4ZGWxQEYzhI',
#  'https://www.youtube.com/watch?v=4kr8EIXgMYk',
#  'https://www.youtube.com/watch?v=AkXIYQusF38',
#  'https://www.youtube.com/watch?v=GQws_qYdCz8',
#  'https://www.youtube.com/watch?v=dIQznq0k-gw',
#  'https://www.youtube.com/watch?v=vgEt7DCYVVo',
#  'https://www.youtube.com/watch?v=WRNsXTyeZI0',
#  'https://www.youtube.com/watch?v=d2JrfO1mNYU',
#  'https://www.youtube.com/watch?v=zU8dXfKkVFg',
#  'https://www.youtube.com/watch?v=VKt_iaAyRyk',
#  'https://www.youtube.com/watch?v=IWQMvcq1yv0']

# %%
# download videos in the 'simple' class using the urls extracted from the dataset
simple_save_path = 'Downloaded Videos/Simple Videos'

print(f"Downloading Simple Videos:")

for n, url in enumerate(simple_video_urls):
    is_name_changed, video_filename = download_video(n+1, url, simple_save_path)
    
    # change the video's name in the dataset if the video's filename is changed due to having the same name as an existing file
    if is_name_changed:
        new_video_name, extension = os.path.splitext(video_filename)
        pcd_df.loc[pcd_df['Video URL'] == url, 'Video Name'] = new_video_name
        print(f"---Video name is changed in the presentation complexity dataset from '{yt(url).title}' to '{new_video_name}'---")
# Out:
# Downloading Simple Videos:
# Video 1: Downloaded successfully
# Video 2: Downloaded successfully
# Video 3: Downloaded successfully
# Video 4: Downloaded successfully
# Video 5: Downloaded successfully
# Video 6: Downloaded successfully
# Video 7: Downloaded successfully
# Video 8: Downloaded successfully
# Video 9: Downloaded successfully
# Video 10: Downloaded successfully
# Video 11: Downloaded successfully
# Video 12: Downloaded successfully
# Video 13: Downloaded successfully
# Video 14: Downloaded successfully
# Video 15: Downloaded successfully
# Video 16: Downloaded successfully
# Video 17: Downloaded successfully
# Video 18: Downloaded successfully
# Video 19: Downloaded successfully
# Video 20: Downloaded successfully
# Video 21: Downloaded successfully
# Video 22: Downloaded successfully
# Video 23: Downloaded successfully
# Video 24: Downloaded successfully
# Video 25: Downloaded successfully
# Video 26: Downloaded successfully
# Video 27: Downloaded successfully
# Video 28: Downloaded successfully
# Video 29: Downloaded successfully
# Video 30: Downloaded successfully
# Video 31: Downloaded successfully
# Video 32: Downloaded successfully
# Video 33: Downloaded successfully
# Video 34: Downloaded successfully
# Video 35: Downloaded successfully
# Video 36: Downloaded successfully
# Video 37: Downloaded successfully
# Video 38: Downloaded successfully
# Video 39: Downloaded successfully
# Video 40: Downloaded successfully
# Video 41: Downloaded successfully
# Video 42: Downloaded successfully
# Video 43: Downloaded successfully
# Video 44: Downloaded successfully
# Video 45: Downloaded successfully
# Video 46: Downloaded successfully
# Video 47: Downloaded successfully
# Video 48: Downloaded successfully
# Video 49: Downloaded successfully
# Video 50: Downloaded successfully
# Video 51: Downloaded successfully
# Video 52: Downloaded successfully
# Video 53: Downloaded successfully
# Video 54: Downloaded successfully
# Video 55: Downloaded successfully
# Video 56: Downloaded successfully
# Video 57: Downloaded successfully
# Video 58: Downloaded successfully
# Video 59: Downloaded successfully
# Video 60: Downloaded successfully
# Video 61: Downloaded successfully
# Video 62: Downloaded successfully
# Video 63: Downloaded successfully
# Video 64: Downloaded successfully
# Video 65: Downloaded successfully
# Video 66: Downloaded successfully
# Video 67: Downloaded successfully
# Video 68: Downloaded successfully
# Video 69: Downloaded successfully
# Video 70: Downloaded successfully
# Video 71: Downloaded successfully
# Video 72: Downloaded successfully
# Video 73: Downloaded successfully
# Video 74: Downloaded successfully
# Video 75: Downloaded successfully
# Video 76: Downloaded successfully
# Video 77: Downloaded successfully
# Video 78: Downloaded successfully
# Video 79: Downloaded successfully
# Video 80: Downloaded successfully
# Video 81: Downloaded successfully
# Video 82: Downloaded successfully
# Video 83: Downloaded successfully
# Video 84: Downloaded successfully
# Video 85: Downloaded successfully
# Video 86: Downloaded successfully
# ---Video name is changed in the presentation complexity dataset from 'Naming Metal and Non metal Grade 10' to 'Naming Metal and Non metal Grade 10_1'---
# Video 87: Downloaded successfully
# Video 88: Downloaded successfully
# Video 89: Downloaded successfully
# Video 90: Downloaded successfully
# Video 91: Downloaded successfully
# Video 92: Downloaded successfully
# Video 93: Downloaded successfully
# Video 94: Downloaded successfully

# %%
# extract the urls of the videos in the 'hard' class from the presentation complexity dataset
hard_video_urls = list(pcd_df.loc[pcd_df['Complexity Level'] == 'hard', 'Video URL']) 
hard_video_urls
# Out:
# ['https://www.youtube.com/watch?v=bdBOVJlHtJE',
#  'https://www.youtube.com/watch?v=eQgoDAsUW7Y',
#  'https://www.youtube.com/watch?v=FkRmFMwYcTA',
#  'https://www.youtube.com/watch?v=Xbi5aqiRoSU',
#  'https://www.youtube.com/watch?v=y-qf_h_LmY0',
#  'https://www.youtube.com/watch?v=HQJ8E5kdgbw',
#  'https://www.youtube.com/watch?v=_SbKuvv-Jok',
#  'https://www.youtube.com/watch?v=MOlyYI6YdH0',
#  'https://www.youtube.com/watch?v=bVxUqES_-LY',
#  'https://www.youtube.com/watch?v=yIx-yi23Kro',
#  'https://www.youtube.com/watch?v=Jsu0HRcC40k',
#  'https://www.youtube.com/watch?v=dtGI9E5_0_o',
#  'https://www.youtube.com/watch?v=i5QmUTkD-cQ',
#  'https://www.youtube.com/watch?v=7ecCApEIoHI',
#  'https://www.youtube.com/watch?v=bcB7EKRqP9A',
#  'https://www.youtube.com/watch?v=ntQDtwr12tE',
#  'https://www.youtube.com/watch?v=lj6ApYHiaWg',
#  'https://www.youtube.com/watch?v=BA0kznlaVFY',
#  'https://www.youtube.com/watch?v=bi2CLSuTmcs',
#  'https://www.youtube.com/watch?v=RdqYqgyaiwI',
#  'https://www.youtube.com/watch?v=UNIQ14Fyjjs',
#  'https://www.youtube.com/watch?v=izeby2uBVAk',
#  'https://www.youtube.com/watch?v=dHQ1BFuFmxM',
#  'https://www.youtube.com/watch?v=THyQ8iJZFck',
#  'https://www.youtube.com/watch?v=ghuuJNusnWE',
#  'https://www.youtube.com/watch?v=5X9VPVt29ks',
#  'https://www.youtube.com/watch?v=qg7kfYGJ33s',
#  'https://www.youtube.com/watch?v=eyNj6UGFMB4',
#  'https://www.youtube.com/watch?v=h3yrPbid43s',
#  'https://www.youtube.com/watch?v=1UYGhBT9urQ',
#  'https://www.youtube.com/watch?v=Zu2nq9_sA_U',
#  'https://www.youtube.com/watch?v=yE4nEpP5XlU',
#  'https://www.youtube.com/watch?v=qVlF00t1SmQ',
#  'https://www.youtube.com/watch?v=Hd2CqfXkNEQ',
#  'https://www.youtube.com/watch?v=IBdaVasXf3g',
#  'https://www.youtube.com/watch?v=H9dp2kj2ffA',
#  'https://www.youtube.com/watch?v=JTePlo1_xrw',
#  'https://www.youtube.com/watch?v=qrHOrYak3xc',
#  'https://www.youtube.com/watch?v=FCpKxXzP4nY',
#  'https://www.youtube.com/watch?v=OJEEHLKFqTU',
#  'https://www.youtube.com/watch?v=WCxwnwBaHAs',
#  'https://www.youtube.com/watch?v=h-nYNXfNqzE',
#  'https://www.youtube.com/watch?v=YdklnHUqvw4',
#  'https://www.youtube.com/watch?v=3RpLhmciXuE',
#  'https://www.youtube.com/watch?v=L2Wi_SRa1Ws',
#  'https://www.youtube.com/watch?v=X_Vdsqqt6Jg',
#  'https://www.youtube.com/watch?v=CFob4wPisgA',
#  'https://www.youtube.com/watch?v=pTa6Q7aizNc',
#  'https://www.youtube.com/watch?v=NLT9LGTQzQQ',
#  'https://www.youtube.com/watch?v=a2UfamERrE8',
#  'https://www.youtube.com/watch?v=5LUoVHGHW5o',
#  'https://www.youtube.com/watch?v=_bnNG1-tiJ0',
#  'https://www.youtube.com/watch?v=aqe1hBBstaw',
#  'https://www.youtube.com/watch?v=0OnqUl9TEds',
#  'https://www.youtube.com/watch?v=TjD9Wn-tQ4A',
#  'https://www.youtube.com/watch?v=KiuM_Rl_r8s',
#  'https://www.youtube.com/watch?v=N8BtUZ8-3y4',
#  'https://www.youtube.com/watch?v=aJvlfi7F-Xw',
#  'https://www.youtube.com/watch?v=igASGXSx8KY',
#  'https://www.youtube.com/watch?v=HndOJzDpIvY',
#  'https://www.youtube.com/watch?v=78n4DdD4vtc',
#  'https://www.youtube.com/watch?v=dANnzmxhlDE',
#  'https://www.youtube.com/watch?v=KHQOgRf2oVA',
#  'https://www.youtube.com/watch?v=wfXwvXEj3RY',
#  'https://www.youtube.com/watch?v=mr3_1Sg7hRY',
#  'https://www.youtube.com/watch?v=oMZKjA6rauo',
#  'https://www.youtube.com/watch?v=gmsf3mc53ok',
#  'https://www.youtube.com/watch?v=D9UqUgzUmqU',
#  'https://www.youtube.com/watch?v=iLTOU3INkkQ',
#  'https://www.youtube.com/watch?v=U2CQbGWnje4',
#  'https://www.youtube.com/watch?v=e-bsMyqa5OM',
#  'https://www.youtube.com/watch?v=ZglTnYjN5vk',
#  'https://www.youtube.com/watch?v=uZVd5ozJUUQ',
#  'https://www.youtube.com/watch?v=W3A3KYmnmyw',
#  'https://www.youtube.com/watch?v=Vka-AeAp6EM',
#  'https://www.youtube.com/watch?v=zfGJ7bsNxt0',
#  'https://www.youtube.com/watch?v=3bOJfnCVFsk']

# %%
# download videos in the 'hard' class using the urls extracted from the dataset
hard_save_path = 'Downloaded Videos/Hard Videos'

print(f"Downloading Hard Videos:")

for n, url in enumerate(hard_video_urls):
    is_name_changed, video_filename = download_video(n+1, url, hard_save_path)
    
    # change the video's name in the dataset if the video's filename is changed due to having the same name as an existing file
    if is_name_changed:
        new_video_name, extension = os.path.splitext(video_filename)
        pcd_df.loc[pcd_df['Video URL'] == url, 'Video Name'] = new_video_name
        print(f"---Video name is changed in the presentation complexity dataset from '{yt(url).title}' to '{new_video_name}'---")
# Out:
# Downloading Hard Videos:
# Video 1: Downloaded successfully
# Video 2: Downloaded successfully
# Video 3: Downloaded successfully
# Video 4: Downloaded successfully
# Video 5: Downloaded successfully
# Video 6: Downloaded successfully
# Video 7: Downloaded successfully
# Video 8: Downloaded successfully
# Video 9: Downloaded successfully
# Video 10: Downloaded successfully
# Video 11: Downloaded successfully
# Video 12: Downloaded successfully
# Video 13: Downloaded successfully
# Video 14: Downloaded successfully
# Video 15: Downloaded successfully
# Video 16: Downloaded successfully
# Video 17: Downloaded successfully
# Video 18: Downloaded successfully
# Video 19: Downloaded successfully
# Video 20: Downloaded successfully
# Video 21: Downloaded successfully
# Video 22: Downloaded successfully
# Video 23: Downloaded successfully
# Video 24: Downloaded successfully
# Video 25: Downloaded successfully
# Video 26: Downloaded successfully
# Video 27: Downloaded successfully
# Video 28: Downloaded successfully
# Video 29: Downloaded successfully
# Video 30: Downloaded successfully
# Video 31: Downloaded successfully
# Video 32: Downloaded successfully
# Video 33: Downloaded successfully
# Video 34: Downloaded successfully
# Video 35: Downloaded successfully
# Video 36: Downloaded successfully
# Video 37: Downloaded successfully
# Video 38: Downloaded successfully
# Video 39: Downloaded successfully
# Video 40: Downloaded successfully
# Video 41: Downloaded successfully
# Video 42: Downloaded successfully
# Video 43: Downloaded successfully
# Video 44: Downloaded successfully
# Video 45: Downloaded successfully
# Video 46: Downloaded successfully
# Video 47: Downloaded successfully
# Video 48: Downloaded successfully
# Video 49: Downloaded successfully
# Video 50: Downloaded successfully
# Video 51: Downloaded successfully
# Video 52: Downloaded successfully
# Video 53: Downloaded successfully
# Video 54: Downloaded successfully
# Video 55: Downloaded successfully
# Video 56: Downloaded successfully
# Video 57: Downloaded successfully
# Video 58: Downloaded successfully
# Video 59: Downloaded successfully
# Video 60: Downloaded successfully
# Video 61: Downloaded successfully
# Video 62: Downloaded successfully
# Video 63: Downloaded successfully
# Video 64: Downloaded successfully
# Video 65: Downloaded successfully
# Video 66: Downloaded successfully
# Video 67: Downloaded successfully
# Video 68: Downloaded successfully
# Video 69: Downloaded successfully
# Video 70: Downloaded successfully
# Video 71: Downloaded successfully
# Video 72: Downloaded successfully
# Video 73: Downloaded successfully
# Video 74: Downloaded successfully
# Video 75: Downloaded successfully
# Video 76: Downloaded successfully
# Video 77: Downloaded successfully
